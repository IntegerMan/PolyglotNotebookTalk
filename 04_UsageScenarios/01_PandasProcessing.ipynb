# %% [markdown]
# ## Using Pandas for Data Processing

# %%
import pandas as pd

# %%
# Read the Titanic dataset into a DataFrame
df = pd.read_csv('titanic.csv')

# Display the top 5 rows of the DataFrame
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# Display last 5 rows
df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1305     3.0       0.0      Zabour, Miss. Thamine  female   NaN    1.0    0.0
# 1306     3.0       0.0  Zakarian, Mr. Mapriededer    male  26.5    0.0    0.0
# 1307     3.0       0.0        Zakarian, Mr. Ortin    male  27.0    0.0    0.0
# 1308     3.0       0.0         Zimmerman, Mr. Leo    male  29.0    0.0    0.0
# 1309     NaN       NaN                        NaN     NaN   NaN    NaN    NaN
#
#       ticket     fare cabin embarked boat   body home.dest
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN
# 1309     NaN      NaN   NaN      NaN  NaN    NaN       NaN

# %%
# Drop rows with NaNs in sensitive columns
df = df.dropna(subset=['pclass', 'survived'])
df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304     3.0       0.0       Zabour, Miss. Hileni  female  14.5    1.0    0.0
# 1305     3.0       0.0      Zabour, Miss. Thamine  female   NaN    1.0    0.0
# 1306     3.0       0.0  Zakarian, Mr. Mapriededer    male  26.5    0.0    0.0
# 1307     3.0       0.0        Zakarian, Mr. Ortin    male  27.0    0.0    0.0
# 1308     3.0       0.0         Zimmerman, Mr. Leo    male  29.0    0.0    0.0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
# Perform statistical analysis on columns
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
# Rename Confusing Columns
df = df.rename(columns={'parch': 'Parents and Children Aboard', 
                        'sibsp': 'Siblings and Spouses Aboard'})

# Rename confusing values
df['embarked'] = df['embarked'].map({'C': 'Cherbourg', 
                                     'Q': 'Queenstown', 
                                     'S': 'Southampton'})

df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  Siblings and Spouses Aboard  Parents and Children Aboard  ticket  \
# 0  29.0000                          0.0                          0.0   24160
# 1   0.9167                          1.0                          2.0  113781
# 2   2.0000                          1.0                          2.0  113781
# 3  30.0000                          1.0                          2.0  113781
# 4  25.0000                          1.0                          2.0  113781
#
#        fare    cabin     embarked boat   body                        home.dest
# 0  211.3375       B5  Southampton    2    NaN                     St Louis, MO
# 1  151.5500  C22 C26  Southampton   11    NaN  Montreal, PQ / Chesterville, ON
# 2  151.5500  C22 C26  Southampton  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3  151.5500  C22 C26  Southampton  NaN  135.0  Montreal, PQ / Chesterville, ON
# 4  151.5500  C22 C26  Southampton  NaN    NaN  Montreal, PQ / Chesterville, ON

# %%
# Get unique values
df['embarked'].unique()
# Out:
# array(['Southampton', 'Cherbourg', nan, 'Queenstown'], dtype=object)

# %%
# Replace NaN values in a column
df['embarked'] = df['embarked'].fillna('Unknown')
df['embarked'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Unknown', 'Queenstown'], dtype=object)

# %%
# We can also remove all rows with a specific value

df = df[df['embarked'].ne('Unknown')] # ne = not equal to

df['embarked'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown'], dtype=object)

# %%
# Add in calculated columns
df['cabin_letter'] = df['cabin'].str[0]
df['is_male'] = (df['sex'] == 'male').map({True: 1, False :0 })
df['Total Family Aboard'] = df['Parents and Children Aboard'] + df['Siblings and Spouses Aboard']

# Drop the columns we no longer care about
df = df.drop(columns=['name', 'cabin', 'ticket', 'home.dest', 'body', 'boat'])

df.head()
# Out:
#    pclass  survived     sex      age  Siblings and Spouses Aboard  \
# 0     1.0       1.0  female  29.0000                          0.0
# 1     1.0       1.0    male   0.9167                          1.0
# 2     1.0       0.0  female   2.0000                          1.0
# 3     1.0       0.0    male  30.0000                          1.0
# 4     1.0       0.0  female  25.0000                          1.0
#
#    Parents and Children Aboard      fare     embarked cabin_letter  is_male  \
# 0                          0.0  211.3375  Southampton            B        0
# 1                          2.0  151.5500  Southampton            C        1
# 2                          2.0  151.5500  Southampton            C        0
# 3                          2.0  151.5500  Southampton            C        1
# 4                          2.0  151.5500  Southampton            C        0
#
#    Total Family Aboard
# 0                  0.0
# 1                  3.0
# 2                  3.0
# 3                  3.0
# 4                  3.0

# %%
# Export to a new CSV file now that processing is completed
df.to_csv('Titanic_Processed.csv')

# %% [markdown]
# ### Grouping

# %%
df_grouped = df.groupby('pclass').agg('mean')

df_grouped.head()
# Out:
#         survived        age  Siblings and Spouses Aboard  \
# pclass
# 1.0     0.616822  39.083038                     0.439252
# 2.0     0.429603  29.506705                     0.393502
# 3.0     0.255289  24.816367                     0.568406
#
#         Parents and Children Aboard       fare   is_male  Total Family Aboard
# pclass
# 1.0                        0.367601  87.555777  0.557632             0.806854
# 2.0                        0.368231  21.179196  0.617329             0.761733
# 3.0                        0.400564  13.302889  0.695346             0.968970

# %% [markdown]
# ### Simple Data Visualization

# %%
df.plot(kind='scatter', 
        x='Parents and Children Aboard', 
        xlabel='# Parents / Children', 
        y='Siblings and Spouses Aboard',
        ylabel='# Siblings / Spouses')
# Out:
# <AxesSubplot:xlabel='Parents and Children Aboard', ylabel='Siblings and Spouses Aboard'>

# %%
df.plot(kind='scatter', 
        x='Total Family Aboard', 
        xlabel='# Dependents', 
        y='survived',
        ylabel='Survived?')
# Out:
# <AxesSubplot:xlabel='Total Family Aboard', ylabel='survived'>
